# %% [markdown]
# **Visualization** is a very integral part of data science. It helps in communicating a pattern or a relationship that cannot be seen by looking at raw data. It's easier for a person to remember a picture and recollect it as compared to lines of text. This holds true for data too.
#
# **Basic Plot**

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,2,3,2,2,1])

# %% [markdown]
# The basic plot in matplotlib contains the following elements:
# x and y axes: These are both horizontal and vertical axes.
# x and y tickers: These are little tickers denoting the segments of axes. There can be major and minor tickers.
# x and y tick labels: These represent values on particular axis.
# Plotting area: This is where the actual plots are drawn.

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], linewidth=4.0)
# increasing the line width
plt.show()

# %% [markdown]
# *Using* **setp()** and **setter()**

# %%
line, = plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
line.set_linestyle('--') # Setting dashed lines
plt.show()

# %%
line, = plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.setp(line, color='r', linewidth=2.0)
# set width of the line
# setting the color
plt.show()

# %% [markdown]
# **`Using legend()`**

# %%
# importing modules
import numpy as np
import matplotlib.pyplot as plt
  
# Y-axis values
y1 = [2, 3, 4.5]
  
# Y-axis values 
y2 = [1, 1.5, 5]
  
# Function to plot  
plt.plot(y1)
plt.plot(y2)
  
# Function add a legend  
plt.legend(["blue", "green"], loc ="lower right")
  
# function to show the plot
plt.show()

# %% [markdown]
# **Creating multiple plots**
#
# One very useful feature of matplotlib is that it makes it easy to plot multiple plots,which can be compared to each other:

# %%
import numpy as np
p1 = np.arange(0.0, 30.0, 0.1)
plt.subplot(211)
plt.plot(p1, np.sin(p1)/p1, 'b--')
plt.subplot(212)
plt.plot(p1, np.cos(p1), 'r--')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.

# %% [markdown]
# **Styling plots**
#
# The style package within the matplotlib library makes it easier to change the style of the plots that are being plotted. It is very easy to change to the famous ggplot style of the R language. **plt.style.use()** is used to set the style of the plot. It is a
# global set, so after it is executed, all the plots that follow will have the same style.

# %%
plt.style.use('ggplot')
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %% [markdown]
# **Box plot**
#
# A box plot is a very good plot to understand the spread, median, and outliers of data:
#
#
# ![pic3.png](data:image/png;base64,...)
# The various parts of the preceding figure are explained as follows:
# • Q3: This is the 75 th percentile value of the data. It's also called the upper hinge.
# • Q1: This is the 25 th percentile value of the data. It's also called the lower hinge.
# • Box: This is also called a step. It's the difference between the upper hinge and the lower hinge.
# • Median: This is the midpoint of the data.
# • Max: This is the upper inner fence. It is 1.5 times the step above Q3.
# • Min: This is the lower inner fence. It is 1.5 times the step below Q1.
# Any value that is greater than Max or lesser than Min is called an outlier, which is also known as a flier.

# %%
## Creating some data
np.random.seed(10)
box_data_1 = np.random.normal(100, 10, 200)
box_data_2 = np.random.normal(80, 30, 200)
box_data_3 = np.random.normal(90, 20, 200)
## Combining the different data in a list
data_to_plot = [box_data_1, box_data_2, box_data_3]
# Create the boxplot
bp = plt.boxplot(data_to_plot)

# %% [markdown]
# **Styling box plot**

# %%
## add patch_artist=True option to ax.boxplot()
## to get fill color
bp = plt.boxplot(data_to_plot, patch_artist=True)
## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
# change outline color
  box.set( color='#7570b3', linewidth=2)
# change fill color
  box.set( facecolor = '#1b9e77' )
## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
  whisker.set(color='#7570b3', linewidth=2)
## change color and linewidth of the caps
for cap in bp['caps']:
  cap.set(color='#7570b3', linewidth=2)
## change color and linewidth of the medians
for median in bp['medians']:
  median.set(color='#b2df8a', linewidth=2)
## change the style of fliers and their fill
for flier in bp['fliers']:
  flier.set(marker='o', color='#e7298a', alpha=0.5)

# %% [markdown]
# **HEATMAPS**
#
# A heatmap is a graphical representation where individual values of a matrix are
# represented as colors. A heatmap is very useful in visualizing the concentration of
# values between two dimensions of a matrix. This helps in finding patterns and gives
# a perspective of depth.

# %%
# Generate Data
data = np.random.rand(10,6)#creates an array of specified shape and fills it with random values.
rows = list('ZYXWVUTSRQ')
columns = list('ABCDEF')
#Ylabel
#Xlabel
 #Basic Heat Map plot
plt.pcolor(data)#to create the heatmap colors.
plt.show()

# %% [markdown]
# **Adding labels**

# %%
# Add Row/Column Labels
plt.pcolor(data)
plt.xticks(np.arange(0,6)+0.5,columns)
plt.yticks(np.arange(0,10)+0.5,rows)
plt.show()

# %% [markdown]
# **Adjust the color of the heatmap to make it more visually representative.**

# %%
# Change color map
plt.pcolor(data,cmap=plt.cm.Reds,edgecolors='k')
plt.xticks(np.arange(0,6)+0.5,columns)
plt.yticks(np.arange(0,10)+0.5,rows)
plt.show()

# %% [markdown]
# **Bubble Chart**
#
# A bubble chart is basically a scatter plot with an additional dimension. The
# additional dimension helps in setting the size of the bubble, which means that the
# greater the size of the bubble, the larger the value that represents the bubble. This
# kind of a chart helps in analyzing the data of three dimensions.

# %%
import pandas as pd
plt.style.use('ggplot')
df = pd.DataFrame(np.random.rand(50, 3), columns=['a', 'b', 'c'])
df.plot(kind='scatter', x='a', y='b', s=df['c']*400);
##plot() method where its kind is mentioned as a scatter 
## s is the size of the bubble:

# %% [markdown]
# **Hexagon bin plot**
#
# A hexagon bin plot can be created using the DataFrame.plot() function and kind
# = 'hexbin' . This kind of plot is really useful if your scatter plot is too dense to
# interpret. It helps in binning the spatial area of the chart and the intensity of the color
# that a hexagon can be interpreted as points being more concentrated in this area.

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000)
df.plot(kind='hexbin', x='a', y='b', gridsize=25)

# %% [markdown]
# **Plotting Curves of a given equation**

# %%
# importing the required modules
import matplotlib.pyplot as plt
import numpy as np
  
# setting the x - coordinates
x = np.arange(0, 2*(np.pi), 0.1)
# setting the corresponding y - coordinates
y = np.sin(x)
  
# potting the points
plt.plot(x, y)
  
# function to show the plot
plt.show()

# %% [markdown]
# **Column chart**
#
#
# A column chart is used to show a comparison among different attributes, or it can show a comparison of items over time.

# %%
# import pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt
  
# create 2D array of table given above
data = [['E001', 'M', 34, 123, 'Normal', 350],
        ['E002', 'F', 40, 114, 'Overweight', 450],
        ['E003', 'F', 37, 135, 'Obesity', 169],
        ['E004', 'M', 30, 139, 'Underweight', 189],
        ['E005', 'F', 44, 117, 'Underweight', 183],
        ['E006', 'M', 36, 121, 'Normal', 80],
        ['E007', 'M', 32, 133, 'Obesity', 166],
        ['E008', 'F', 26, 140, 'Normal', 120],
        ['E009', 'M', 32, 133, 'Normal', 75],
        ['E010', 'M', 36, 133, 'Underweight', 40] ]
  
# dataframe created with
# the above data array
df = pd.DataFrame(data, columns = ['EMPID', 'Gender', 
                                    'Age', 'Sales',
                                    'BMI', 'Income'] )
df.plot.bar()
  
# plot between 2 attributes
plt.bar(df['Age'], df['Sales'])
plt.xlabel("Age")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# **3D plot**

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')
